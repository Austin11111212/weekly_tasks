# %%
# !pip install pandas

# %%
import pandas as pd
import numpy as mp
import plotly.express as px

# %%
df = pd.read_csv('/content/spotify-2023 2.csv', encoding = 'Latin')

# %%
df.head()
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
# 2                              vampire    Olivia Rodrigo             1
# 3                         Cruel Summer      Taylor Swift             1
# 4                       WHERE SHE GOES         Bad Bunny             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
# 2           2023               6            30                  1397
# 3           2019               8            23                  7858
# 4           2023               5            18                  3133
#
#    in_spotify_charts    streams  in_apple_playlists  ...  bpm key   mode  \
# ...

# %%
fig = px.pie(df,values = 'streams',names = 'released_month',hole = 0.25)
fig.update_traces(textposition='inside', textinfo='percent+label')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df.sort_values(by = 'artist_count', ascending = False, inplace = True)
sample_data = df.head(15)

# %%
sample_data
# Out:
#                                             track_name  \
# 642                                           Se Le Ve
# 35                                     Los del Espacio
# 667  Cayï¿½ï¿½ La Noche (feat. Cruz Cafunï¿½ï¿½, Ab...
# 506                          We Don't Talk About Bruno
# 393                                  Jhoome Jo Pathaan
# 759                 Nobody Like U - From "Turning Red"
# 402                     Besharam Rang (From "Pathaan")
# 864                                   ULTRA SOLO REMIX
# 328                                   Marisola - Remix
# 201  Angel Pt 1 (feat. Jimin of BTS, JVKE & Muni Long)
# 137        Tere Vaaste (From "Zara Hatke Zara Bachke")
# 238  Link Up (Metro Boomin & Don Toliver, Wizkid fe...
# 488                                    Tubarï¿½ï¿½o Te
# 200  Annihilate (Spider-Man: Across the Spider-Vers...
# 197                                    POLARIS - Remix
#
#                                         artist(s)_name  artist_count  \
# ...

# %%
fig = px.bar(sample_data, y = 'artist(s)_name',x = 'artist_count', width = 500, height = 500, title = 'spotify data')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['streams'] = pd.to_numeric(df['streams'],errors = 'coerce')

# %%
df.sort_values(by = 'streams', ascending = False, inplace = True)

# %%
fig = px.scatter(df,x = 'streams',y = 'released_day',color = 'released_month')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df['streams'].mode()
# Out:
# 0    1.563386e+08
# 1    3.955914e+08
# 2    7.238945e+08
# 3    1.223481e+09
# Name: streams, dtype: float64

# %%
df['released_month'].value_counts().reset_index()
# Out:
#     released_month  count
# 0                1    134
# 1                5    128
# 2                6     86
# 3                3     86
# 4               11     80
# 5               12     75
# 6               10     73
# 7                4     66
# 8                7     62
# 9                2     61
# 10               9     56
# 11               8     46

# %%
fig = px.scatter(df,x = 'streams',y = 'released_day',size = 'released_month',color = 'released_month')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df = df.groupby('artist_count')['streams'].mean().reset_index().sort_values(by = 'artist_count', ascending = True).reset_index(drop=True)
df = df.head()

# %%
fig= px.funnel(df,y= 'streams',x = 'artist_count')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-9f0e64e0ec4c> in <cell line: 2>()
#       1 # Two random agents play one game round
# ----> 2 env.run(["random", "random"])
#       3
#       4 # Show the game
#       5 env.render(mode="ipython")
#
# NameError: name 'env' is not defined
