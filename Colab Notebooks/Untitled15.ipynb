# %%
X = [20,15,40,60,10,30,50]
y = [2,3,5,7,1,3,6]

# %%
import plotly.express as px

# %%
px.scatter(x=X,y=Y,width=900,height = 600)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
from sklearn import metrics

# %%
xtrain,xtest,ytrain,ytest=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
print('xtrain shape: ',len(xtrain))
print('xtest shape: ',len(xtest))
print('ytrain shape: ',len(ytrain))
print('ytest shape: ',len(ytest))
# Out:
# xtrain shape:  5
# xtest shape:  2
# ytrain shape:  5
# ytest shape:  2

# %%
model=LinearRegression()

# %%
# xtrain=np.array(xtrain).reshape(-1,1)
# xtest=np.array(xtest).reshape(-1,1)

# %%
xtrain=np.array(xtrain)

# %%
model.fit(xtrain.reshape(-1,1),ytrain)
# Out:
# LinearRegression()

# %%
ytest,predicted
# Out:
# ([6, 5], array([5.71835443, 4.62341772]))

# %%
xtest
# Out:
# [50, 40]

# %%
model.predict(xtest.reshape(-1,1))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-34-4ef3dd7afe5a> in <cell line: 1>()
# ----> 1 model.predict(xtest.reshape(-1,1))
#
# AttributeError: 'list' object has no attribute 'reshape'

# %%
import numpy as np

# Convert xtest to a NumPy array before reshaping
xtest_array = np.array(xtest)
model.predict(xtest_array.reshape(-1,1))
# Out:
# array([5.71835443, 4.62341772])

# %%
predicted = model.predict(xtest_array.reshape(-1,1)) # Store the result of the prediction

# %%
mean_squared_error(ytest,predicted)
# Out:
# 0.11056921967633387

# %%
import numpy as np

# Convert xtest to a NumPy array before reshaping
xtest_array = np.array(xtest)
predicted = model.predict(xtest_array.reshape(-1,1)) # Store the result of the prediction

mean_squared_error(ytest,predicted)
# Out:
# 0.11056921967633387

# %%
# slop
model.coef_
# Out:
# array([0.10949367])

# %%
model.intercept_
# Out:
# 0.24367088607594933

# %%
pred = 0.109 * np.array(X) + 0.244

# %%
pred
# Out:
# array([2.424, 1.879, 4.604, 6.784, 1.334, 3.514, 5.694])

# %%
px.scatter(x=X,y=Y[y
