# %%
import pandas as pd

# %%
df = pd.read_csv('/content/Africa_climate_change (1).csv')

# %%
df.head()
# Out:
#               DATE  PRCP  TAVG  TMAX  TMIN   COUNTRY
# 0  19800101 000000   NaN  54.0  61.0  43.0   Tunisia
# 1  19800101 000000   NaN  49.0  55.0  41.0   Tunisia
# 2  19800101 000000   0.0  72.0  86.0  59.0  Cameroon
# 3  19800101 000000   NaN  50.0  55.0  43.0   Tunisia
# 4  19800101 000000   NaN  75.0  91.0   NaN  Cameroon

# %%
df.drop([''])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-25-e7d8a662abc7> in <cell line: 1>()
# ----> 1 df.drop(['PRCP'])
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5256                 weight  1.0     0.8
#    5257         """
# -> 5258         return super().drop(
#    5259             labels=labels,
#    5260             axis=axis,
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4547         for axis, labels in axes.items():
#    4548             if labels is not None:
# -> 4549                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4550
#    4551         if inplace:
#
# ...

# %%
# checking for missing values
print(df.isnull().sum())
# Out:
# DATE          0
# PRCP       9684
# TAVG       2252
# TMAX       4579
# TMIN       4970
# COUNTRY       1
# dtype: int64

# %%
# Drop rows with missing values (if applicable)
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Check data types and consistency
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10987 entries, 2 to 26104
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   DATE     10987 non-null  object
#  1   PRCP     10987 non-null  float64
#  2   TAVG     10987 non-null  float64
#  3   TMAX     10987 non-null  float64
#  4   TMIN     10987 non-null  float64
#  5   COUNTRY  10987 non-null  object
# dtypes: float64(4), object(2)
# memory usage: 600.9+ KB
# None

# %%
# Attempt to infer the format automatically, handling mixed formats if necessary
df['DATE'] = pd.to_datetime(df['DATE'],  format='mixed', errors='coerce')

# %%
df['DATE']
# Out:
# 2       1980-01-01
# 6       1980-01-01
# 7       1980-01-01
# 8       1980-01-01
# 9       1980-01-01
#            ...
# 26094   1982-12-14
# 26095   1982-12-14
# 26102   1982-12-14
# 26103   1982-12-14
# 26104   1982-12-14
# Name: DATE, Length: 10987, dtype: datetime64[ns]

# %%
df.head()
# Out:
#         DATE  PRCP  TAVG  TMAX  TMIN   COUNTRY
# 2 1980-01-01   0.0  72.0  86.0  59.0  Cameroon
# 6 1980-01-01   0.0  76.0  97.0  59.0   Senegal
# 7 1980-01-01   0.0  74.0  95.0  59.0   Senegal
# 8 1980-01-01   0.0  78.0  93.0  63.0   Senegal
# 9 1980-01-01   0.0  76.0  91.0  59.0   Senegal

# %% [markdown]
# Plotting Average Temperature Fluctuations in Tunisia and Cameroon

# %%
# Filter data for Tunisia and Cameroon
tunisia_cameroon = df[df['COUNTRY'].isin(['Tunisia', 'Cameroon'])]

# %%
tunisia_cameroon
# Out:
#             DATE  PRCP  TAVG  TMAX  TMIN   COUNTRY
# 2     1980-01-01   0.0  72.0  86.0  59.0  Cameroon
# 31    1980-01-02   0.0  75.0  91.0  61.0  Cameroon
# 41    1980-01-02   0.0  81.0  90.0  75.0  Cameroon
# 43    1980-01-02   0.0  76.0  95.0  59.0  Cameroon
# 66    1980-01-03   0.0  80.0  91.0  73.0  Cameroon
# ...          ...   ...   ...   ...   ...       ...
# 26081 1982-12-13   0.0  50.0  58.0  43.0   Tunisia
# 26094 1982-12-14   0.0  57.0  69.0  53.0   Tunisia
# 26095 1982-12-14   0.0  55.0  63.0  50.0   Tunisia
# 26103 1982-12-14   0.0  51.0  62.0  41.0   Tunisia
# 26104 1982-12-14   0.0  54.0  60.0  50.0   Tunisia
#
# [2399 rows x 6 columns]

# %%
tp_data = tunisia_cameroon.groupby('COUNTRY')['TAVG'].mean().reset_index()

# %%
tp_data.head()
# Out:
#     COUNTRY       TAVG
# 0  Cameroon  77.781927
# 1   Tunisia  69.853774

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder

# %%
import plotly.express as px
px.line(tp_data, x='COUNTRY', y='TAVG', title='Temp_data_line_chart')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Zooming in to 1980-2005 for Tunisia and Cameroon

# %%
# Filter data for Tunisia and Cameroon
df_tc = df[df['COUNTRY'].isin(['Tunisia', 'Cameroon'])]

# %%
df_tc
# Out:
#             DATE  PRCP  TAVG  TMAX  TMIN   COUNTRY
# 2     1980-01-01   0.0  72.0  86.0  59.0  Cameroon
# 31    1980-01-02   0.0  75.0  91.0  61.0  Cameroon
# 41    1980-01-02   0.0  81.0  90.0  75.0  Cameroon
# 43    1980-01-02   0.0  76.0  95.0  59.0  Cameroon
# 66    1980-01-03   0.0  80.0  91.0  73.0  Cameroon
# ...          ...   ...   ...   ...   ...       ...
# 26081 1982-12-13   0.0  50.0  58.0  43.0   Tunisia
# 26094 1982-12-14   0.0  57.0  69.0  53.0   Tunisia
# 26095 1982-12-14   0.0  55.0  63.0  50.0   Tunisia
# 26103 1982-12-14   0.0  51.0  62.0  41.0   Tunisia
# 26104 1982-12-14   0.0  54.0  60.0  50.0   Tunisia
#
# [2399 rows x 6 columns]

# %%
# Filter data between 1980 and 2005
df_tc_zoomed = df_tc[(df_tc['DATE'] >= 1980) & (df_tc['DATE'] <= 2005)]
# Out:
# ---------------------------------------------------------------------------
# InvalidComparison                         Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimelike.py in _cmp_method(self, other, op)
#     934         try:
# --> 935             other = self._validate_comparison_value(other)
#     936         except InvalidComparison:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/arrays/datetimelike.py in _validate_comparison_value(self, other)
#     570         elif not is_list_like(other):
# --> 571             raise InvalidComparison(other)
#     572
#
# InvalidComparison: 1980
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-ed5937409f7e> in <cell line: 2>()
#       1 # Filter data between 1980 and 2005
# ----> 2 df_tc_zoomed = df_tc[(df_tc['DATE'] >= 1980) & (df_tc['DATE'] <= 2005)]
#
# ...

# %%
senegal_1980_2005
