# %%
import numpy as np

# %%
with open(r'C:\Users\HP\Downloads\Loan_prediction_dataset (2).csv') as file:
    data = np.genfromtxt(file, delimiter=',',dtype = str)

# %%
data
# Out:
# array([['Loan_ID', 'Gender', 'Married', ..., 'Credit_History',
#         'Property_Area', 'Loan_Status'],
#        ['LP001002', 'Male', 'No', ..., '1', 'Urban', 'Y'],
#        ['LP001003', 'Male', 'Yes', ..., '1', 'Rural', 'N'],
#        ...,
#        ['LP002983', 'Male', 'Yes', ..., '1', 'Urban', 'Y'],
#        ['LP002984', 'Male', 'Yes', ..., '1', 'Urban', 'Y'],
#        ['LP002990', 'Female', 'No', ..., '0', 'Semiurban', 'N']],
#       dtype='<U17')

# %%
data[1:,8]
# Out:
# array(['0', '128', '66', '120', '141', '267', '95', '158', '168', '349',
#        '70', '109', '200', '114', '17', '125', '100', '76', '133', '115',
#        '104', '315', '116', '112', '151', '191', '122', '110', '35',
#        '120', '201', '74', '106', '114', '320', '0', '100', '144', '184',
#        '110', '80', '47', '75', '134', '96', '88', '44', '144', '120',
#        '144', '100', '120', '112', '134', '286', '97', '96', '135', '180',
#        '144', '120', '99', '165', '0', '116', '258', '126', '312', '125',
#        '136', '172', '97', '81', '95', '187', '113', '176', '110', '180',
#        '130', '111', '0', '167', '265', '50', '136', '99', '104', '210',
#        '175', '131', '188', '81', '122', '25', '0', '137', '50', '115',
#        '131', '133', '151', '0', '0', '160', '100', '225', '120', '216',
#        '94', '136', '139', '152', '0', '118', '185', '154', '85', '175',
#        '259', '180', '44', '137', '81', '194', '93', '370', '0', '160',
# ...

# %%
data[1:,8].astype(float).mean()
# Out:
# 140.95114006514657

# %%
data[1:,8].astype(float).median()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[33], line 1
# ----> 1 data[1:,8].astype(float).median()
#
# AttributeError: 'numpy.ndarray' object has no attribute 'median'

# %%
data[1:,8].astype(float).std()
# Out:
# 88.4512833967426

# %%
np.meadian(data[1:,8])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 np.meadian(data[1:,8])
#
# File ~\anaconda3\Lib\site-packages\numpy\__init__.py:333, in __getattr__(attr)
#     330     "Removed in NumPy 1.25.0"
#     331     raise RuntimeError("Tester was removed in NumPy 1.25.")
# --> 333 raise AttributeError("module {!r} has no attribute "
#     334                      "{!r}".format(__name__, attr))
#
# AttributeError: module 'numpy' has no attribute 'meadian'

# %%
loan = data[1:,8].astype(float)

# %%
loan
# Out:
# array([  0., 128.,  66., 120., 141., 267.,  95., 158., 168., 349.,  70.,
#        109., 200., 114.,  17., 125., 100.,  76., 133., 115., 104., 315.,
#        116., 112., 151., 191., 122., 110.,  35., 120., 201.,  74., 106.,
#        114., 320.,   0., 100., 144., 184., 110.,  80.,  47.,  75., 134.,
#         96.,  88.,  44., 144., 120., 144., 100., 120., 112., 134., 286.,
#         97.,  96., 135., 180., 144., 120.,  99., 165.,   0., 116., 258.,
#        126., 312., 125., 136., 172.,  97.,  81.,  95., 187., 113., 176.,
#        110., 180., 130., 111.,   0., 167., 265.,  50., 136.,  99., 104.,
#        210., 175., 131., 188.,  81., 122.,  25.,   0., 137.,  50., 115.,
#        131., 133., 151.,   0.,   0., 160., 100., 225., 120., 216.,  94.,
#        136., 139., 152.,   0., 118., 185., 154.,  85., 175., 259., 180.,
#         44., 137.,  81., 194.,  93., 370.,   0., 160., 182., 650.,  74.,
#         70.,  25., 102., 290.,  84.,  88., 242., 129., 185., 168., 175.,
# ...

# %%
np.mean(loan)
# Out:
# 140.95114006514657

# %%
np.median(loan)
# Out:
# 125.0

# %%
np.std(loan)
# Out:
# 88.4512833967426
