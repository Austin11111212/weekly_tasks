# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/car45_data.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0                    car_id                        description  \
# 0           0  5IQTDBTYmvK1tJwhdvGJfESJ          Lexus ES 350 FWD 2013 Red
# 1           1  zpZUGomoVXuKk9UFa8j8moC9  Land Rover Range Rover 2012 White
# 2           2  a6ShZXOX4KtY6IBGJIcF3Cxk          Toyota Sequoia 2018 Black
#
#      amount                region        make        model  year_of_man  \
# 0  12937500    Lagos State, Ikeja       Lexus           ES         2013
# 1   6750000  Abuja (FCT), Garki 2  Land Rover  Range Rover         2012
# 2  50625000    Lagos State, Lekki      Toyota      Sequoia         2018
#
#    color      condition  ...  bought_cond     trim  drive_train reg_city seat  \
# 0    Red   Foreign Used  ...     Imported  350 FWD  Front Wheel      NaN    5
# 1  White  Nigerian Used  ...   Registered      NaN          NaN      NaN  NaN
# 2  Black   Foreign Used  ...     Imported      NaN          NaN      NaN  NaN
#
# ...
