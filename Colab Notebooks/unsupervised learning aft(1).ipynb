# %%
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules

# Sample dataset of transactions
data = [
    ['milk', 'bread', 'butter','yam'],
    ['bread', 'butter'],
    ['milk', 'bread','egg','fish'],
    ['milk', 'butter','egg'],
    ['bread'],
    ['milk', 'bread', 'butter'],
    ['bread'],
    ['milk', 'bread'],
    ['bread', 'butter'],
    ['milk', 'bread', 'yam']
]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
data
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['milk', 'bread', 'butter', 'yam'],
#  ['bread', 'butter'],
#  ['milk', 'bread', 'egg', 'fish'],
#  ['milk', 'butter', 'egg'],
#  ['bread'],
#  ['milk', 'bread', 'butter'],
#  ['bread'],
#  ['milk', 'bread'],
#  ['bread', 'butter'],
#  ['milk', 'bread', 'yam']]

# %%
# Convert the dataset to a DataFrame
df = pd.DataFrame(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        0       1       2     3
# 0   milk   bread  butter   yam
# 1  bread  butter    None  None
# 2   milk   bread     egg  fish
# 3   milk  butter     egg  None
# 4  bread    None    None  None
# 5   milk   bread  butter  None
# 6  bread    None    None  None
# 7   milk   bread    None  None
# 8  bread  butter    None  None
# 9   milk   bread     yam  None

# %%
# Initialize the TransactionEncoder
te = TransactionEncoder()

# Fit and transform the data
te_ary = te.fit_transform(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
te_ary
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# array([[ True,  True, False, False,  True,  True],
#        [ True,  True, False, False, False, False],
#        [ True, False,  True,  True,  True, False],
#        [False,  True,  True, False,  True, False],
#        [ True, False, False, False, False, False],
#        [ True,  True, False, False,  True, False],
#        [ True, False, False, False, False, False],
#        [ True, False, False, False,  True, False],
#        [ True,  True, False, False, False, False],
#        [ True, False, False, False,  True,  True]])

# %%
# Convert the transformed data to a DataFrame
df = pd.DataFrame(te_ary, columns=te.columns_)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#    bread  butter    egg   fish   milk    yam
# 0   True    True  False  False   True   True
# 1   True    True  False  False  False  False
# 2   True   False   True   True   True  False
# 3  False    True   True  False   True  False
# 4   True   False  False  False  False  False
# 5   True    True  False  False   True  False
# 6   True   False  False  False  False  False
# 7   True   False  False  False   True  False
# 8   True    True  False  False  False  False
# 9   True   False  False  False   True   True

# %%
frequent_itemsets=apriori(df, min_support=0.2, use_colnames=True)
frequent_itemsets.sort_values('support',ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     support               itemsets
# 0       0.9                (bread)
# 3       0.6                 (milk)
# 1       0.5               (butter)
# 6       0.5          (milk, bread)
# 5       0.4        (butter, bread)
# 8       0.3         (milk, butter)
# 2       0.2                  (egg)
# 4       0.2                  (yam)
# 7       0.2           (yam, bread)
# 9       0.2            (egg, milk)
# 10      0.2            (milk, yam)
# 11      0.2  (milk, butter, bread)
# 12      0.2     (milk, yam, bread)

# %%
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.2).sort_values('confidence',ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents      consequents  antecedent support  consequent support  \
# 8             (egg)           (milk)                 0.2                 0.6
# 22            (yam)    (milk, bread)                 0.2                 0.5
# 4             (yam)          (bread)                 0.2                 0.9
# 20     (yam, bread)           (milk)                 0.2                 0.6
# 18      (milk, yam)          (bread)                 0.2                 0.9
# 11            (yam)           (milk)                 0.2                 0.6
# 2            (milk)          (bread)                 0.6                 0.9
# ...

# %%
association_rules(frequent_itemsets,metric="confidence",min_threshold=0.2).sort_values('lift',ascending=False)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#         antecedents      consequents  antecedent support  consequent support  \
# 22            (yam)    (milk, bread)                 0.2                 0.5
# 19    (milk, bread)            (yam)                 0.5                 0.2
# 8             (egg)           (milk)                 0.2                 0.6
# 9            (milk)            (egg)                 0.6                 0.2
# 10           (milk)            (yam)                 0.6                 0.2
# 11            (yam)           (milk)                 0.2                 0.6
# 21           (milk)     (yam, bread)                 0.6                 0.2
# ...

# %%
####

#class activity
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
import pandas as pd
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df = pd.read_csv('DataSetA.csv',on_bad_lines='skip')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.shape
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# (8731, 7)

# %%
    transaction = [value for value in row if pd.notna(value)]
    transactions.append(transaction)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
df.head(5)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#     Lassi  Coffee Powder         Butter        Yougurt    Ghee Cheese  \
# 0    Ghee  Coffee Powder            NaN            NaN     NaN    NaN
# 1   Lassi     Tea Powder         Butter         Cheese     NaN    NaN
# 2  Cheese     Tea Powder         Panner  Coffee Powder  Butter  Bread
# 3  Cheese        Yougurt  Coffee Powder          Sugar  Butter  Sweet
# 4   Sugar     Tea Powder           Ghee          Sweet  Panner   Milk
#
#    Unnamed: 6
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
transactions = []
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
for index, row in df.head(5).iterrows():
    print(row)
# Out:
# Lassi                     Ghee
# Coffee Powder    Coffee Powder
# Butter                     NaN
# Yougurt                    NaN
# Ghee                       NaN
# Cheese                     NaN
# Unnamed: 6                 NaN
# Name: 0, dtype: object
# Lassi                 Lassi
# Coffee Powder    Tea Powder
# Butter               Butter
# Yougurt              Cheese
# Ghee                    NaN
# Cheese                  NaN
# Unnamed: 6              NaN
# Name: 1, dtype: object
# Lassi                   Cheese
# Coffee Powder       Tea Powder
# Butter                  Panner
# Yougurt          Coffee Powder
# Ghee                    Butter
# Cheese                   Bread
# Unnamed: 6                 NaN
# Name: 2, dtype: object
# Lassi                   Cheese
# Coffee Powder          Yougurt
# Butter           Coffee Powder
# Yougurt                  Sugar
# Ghee                    Butter
# Cheese                   Sweet
# Unnamed: 6                 NaN
# ...

# %%
# if the value is not a na value then append it to the list
for index, row in df.head(5).iterrows():
    transaction = [value for value in row if pd.notna(value)]
    transactions.append(transaction)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transaction
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ['Sugar', 'Tea Powder', 'Ghee', 'Sweet', 'Panner', 'Milk']

# %%
for index, row in df.iterrows():
    transaction = [value for value in row]
    transactions.append(transaction)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
transactions
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [['Ghee', 'Coffee Powder'],
#  ['Lassi', 'Tea Powder', 'Butter', 'Cheese'],
#  ['Cheese', 'Tea Powder', 'Panner', 'Coffee Powder', 'Butter', 'Bread'],
#  ['Cheese', 'Yougurt', 'Coffee Powder', 'Sugar', 'Butter', 'Sweet'],
#  ['Sugar', 'Tea Powder', 'Ghee', 'Sweet', 'Panner', 'Milk'],
#  ['Ghee', 'Coffee Powder', nan, nan, nan, nan, nan],
#  ['Lassi', 'Tea Powder', 'Butter', 'Cheese', nan, nan, nan],
#  ['Cheese', 'Tea Powder', 'Panner', 'Coffee Powder', 'Butter', 'Bread', nan],
#  ['Cheese', 'Yougurt', 'Coffee Powder', 'Sugar', 'Butter', 'Sweet', nan],
#  ['Sugar', 'Tea Powder', 'Ghee', 'Sweet', 'Panner', 'Milk', nan],
# ...

# %%
list1 = [2,3,6,3]
list2 = []
for i in range(len(list1)):
    list2.append(list1[i] * 2)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
list2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# [4, 6, 12, 6]

# %%
list2 = [i * 2 for i in list1]
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
{i * 2 for i in list1}
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# {4, 6, 12}

# %%
# Initialize the TransactionEncoder
te = TransactionEncoder()

# Fit and transform the data
te_ary = te.fit_transform(transactions)
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-151-5dd41a302637> in <cell line: 5>()
#       3
#       4 # Fit and transform the data
# ----> 5 te_ary = te.fit_transform(transactions)
#
# /usr/local/lib/python3.10/dist-packages/sklearn/utils/_set_output.py in wrapped(self, X, *args, **kwargs)
#     138     @wraps(f)
#     139     def wrapped(self, X, *args, **kwargs):
# --> 140         data_to_wrap = f(self, X, *args, **kwargs)
#     141         if isinstance(data_to_wrap, tuple):
# ...

# %%
# Inspect the types of items in your transactions
for transaction in transactions[:5]:  # Check the first 5 transactions
    for item in transaction:
        print(type(item))

# If mixed types are found, consider converting all items to strings:
transactions_str = [[str(item) for item in transaction] for transaction in transactions]

# Initialize the TransactionEncoder
te = TransactionEncoder()

# Fit and transform the data using the stringified transactions
te_ary = te.fit_transform(transactions_str)
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
