# %%
from sklearn.cluster import AgglomerativeClustering
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
X = np.array([[1, 2, 1], [1, 4, 1], [1, 0, 1],
              [4, 2, 0], [4, 4, 0], [4, 0, 0]])

# %%
clustering = AgglomerativeClustering().fit(X)

# %%
AgglomerativeClustering()
# Out:
# AgglomerativeClustering()

# %%
y = np.array([2, 3, 4, 3, 2, 1])

# %%
lr = LinearRegression()

# %%
lr.fit(X, y)
# Out:
# LinearRegression()

# %%
mean_squared_error(y, lr.predict(X))
# Out:
# 0.6666666666666666

# %%
# Unsupervised learning_

# %%
import pandas as pd
data=pd.read_csv('/content/Mall_Customers.csv')

# %%
# you always drop customer Id in machoine learning
data=data.drop("CustomerID", axis=1)
data["Gender"]=data["Gender"].map({"Male":1, "Female":0})  #convert Gender values into numerical
data
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0         1   19                  15                      39
# 1         1   21                  15                      81
# 2         0   20                  16                       6
# 3         0   23                  16                      77
# 4         0   31                  17                      40
# ..      ...  ...                 ...                     ...
# 195       0   35                 120                      79
# 196       0   45                 126                      28
# 197       1   32                 126                      74
# 198       1   32                 137                      18
# 199       1   30                 137                      83
#
# [200 rows x 4 columns]

# %%
from sklearn.cluster import AgglomerativeClustering #Importing our clustering algorithm : Agglomerative
model=AgglomerativeClustering(n_clusters=8, metric='euclidean', linkage='complete')
clust_labels=model.fit_predict(data)  #Applying agglomerative algorithm with 5 clusters, using euclidean distance as a metric

# %%
clust_labels
# Out:
# array([0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3,
#        0, 3, 0, 3, 0, 1, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 3, 0, 1,
#        0, 1, 7, 1, 1, 1, 7, 1, 1, 7, 1, 1, 7, 7, 1, 1, 7, 1, 7, 7, 7, 1,
#        1, 7, 1, 1, 7, 1, 7, 7, 7, 1, 1, 1, 1, 1, 7, 1, 7, 1, 1, 1, 7, 1,
#        1, 7, 7, 1, 7, 1, 1, 1, 7, 1, 7, 1, 1, 7, 7, 1, 7, 1, 7, 7, 7, 7,
#        7, 1, 1, 1, 1, 1, 7, 7, 7, 7, 1, 1, 1, 4, 1, 4, 2, 4, 2, 4, 2, 4,
#        1, 4, 2, 4, 2, 4, 2, 4, 2, 4, 1, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4,
#        2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4,
#        2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 2, 4, 5, 4, 5, 6, 5, 6,
#        5, 6])

# %%
agglomerative=pd.DataFrame(clust_labels,columns=['clusters'])
agglomerative # Display the 'agglomerative' DataFrame
# Out:
#      clusters
# 0           0
# 1           3
# 2           0
# 3           3
# 4           0
# ..        ...
# 195         6
# 196         5
# 197         6
# 198         5
# 199         6
#
# [200 rows x 1 columns]

# %%
data['clusters']=clust_labels
data
# Out:
#      Gender  Age  Annual Income (k$)  Spending Score (1-100)  clusters
# 0         1   19                  15                      39         0
# 1         1   21                  15                      81         3
# 2         0   20                  16                       6         0
# 3         0   23                  16                      77         3
# 4         0   31                  17                      40         0
# ..      ...  ...                 ...                     ...       ...
# 195       0   35                 120                      79         6
# 196       0   45                 126                      28         5
# 197       1   32                 126                      74         6
# 198       1   32                 137                      18         5
# 199       1   30                 137                      83         6
#
# [200 rows x 5 columns]

# %%
import plotly.express as px
fig = px.scatter_3d(data, x='Annual Income (k$)', y='Spending Score (1-100)',width = 800, height = 800, z='Age', color='clusters')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/content/car45_data.csv')

# %%
df.head(3)
# Out:
#    Unnamed: 0                    car_id                        description  \
# 0           0  5IQTDBTYmvK1tJwhdvGJfESJ          Lexus ES 350 FWD 2013 Red
# 1           1  zpZUGomoVXuKk9UFa8j8moC9  Land Rover Range Rover 2012 White
# 2           2  a6ShZXOX4KtY6IBGJIcF3Cxk          Toyota Sequoia 2018 Black
#
#      amount                region        make        model  year_of_man  \
# 0  12937500    Lagos State, Ikeja       Lexus           ES         2013
# 1   6750000  Abuja (FCT), Garki 2  Land Rover  Range Rover         2012
# 2  50625000    Lagos State, Lekki      Toyota      Sequoia         2018
#
#    color      condition  ...  bought_cond     trim  drive_train reg_city seat  \
# 0    Red   Foreign Used  ...     Imported  350 FWD  Front Wheel      NaN    5
# 1  White  Nigerian Used  ...   Registered      NaN          NaN      NaN  NaN
# 2  Black   Foreign Used  ...     Imported      NaN          NaN      NaN  NaN
#
# ...
