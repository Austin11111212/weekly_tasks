# %% [markdown]
# ><h1><center>SPOTIFY 🎵🎵🎵🎵</center></h1>

# %% [markdown]
# **<h2>This dataset contains a comprehensive list of the most famous songs of 2023 as listed on Spotify. The dataset offers a wealth of features beyond what is typically available in similar datasets. It provides insights into each song's attributes, popularity, and presence on various music platforms. The dataset includes information such as track name, artist(s) name, release date, Spotify playlists and charts, streaming statistics, Apple Music presence, Deezer presence, Shazam charts, and various audio features.</h2>**

# %% [markdown]
# * track_name: Name of the song
# * artist(s)_name: Name of the artist(s) of the song
# * artist_count: Number of artists contributing to the song
# * released_year: Year when the song was released
# * released_month: Month when the song was released
# * released_day: Day of the month when the song was released
# * in_spotify_playlists: Number of Spotify playlists the song is included in
# * in_spotify_charts: Presence and rank of the song on Spotify charts
# * streams: Total number of streams on Spotify
# * in_apple_playlists: Number of Apple Music playlists the song is included in
# * in_apple_charts: Presence and rank of the song on Apple Music charts
# * in_deezer_playlists: Number of Deezer playlists the song is included in
# * in_deezer_charts: Presence and rank of the song on Deezer charts
# * in_shazam_charts: Presence and rank of the song on Shazam charts
# * bpm: Beats per minute, a measure of song tempo
# * key: Key of the song
# * mode: Mode of the song (major or minor)
# * danceability_%: Percentage indicating how suitable the song is for dancing
# * valence_%: Positivity of the song's musical content
# * energy_%: Perceived energy level of the song
# * acousticness_%: Amount of acoustic sound in the song
# * instrumentalness_%: Amount of instrumental content in the song
# * liveness_%: Presence of live performance elements
# * speechiness_%: Amount of spoken words in the song

# %%
#import your pandas here
import pandas as pd

# %%
#import your data

df = pd.read_csv('/content/spotify-2023 2.csv', encoding = 'latin')

# %% [markdown]
# **Question 1**
#
# Get the head of 10 for the data

# %%
df.head(10)
# Out:
#                             track_name              artist(s)_name  \
# 0  Seven (feat. Latto) (Explicit Ver.)            Latto, Jung Kook
# 1                                 LALA                 Myke Towers
# 2                              vampire              Olivia Rodrigo
# 3                         Cruel Summer                Taylor Swift
# 4                       WHERE SHE GOES                   Bad Bunny
# 5                             Sprinter           Dave, Central Cee
# 6                      Ella Baila Sola  Eslabon Armado, Peso Pluma
# 7                             Columbia                     Quevedo
# 8                             fukumean                       Gunna
# 9                      La Bebe - Remix       Peso Pluma, Yng Lvcas
#
#    artist_count  released_year  released_month  released_day  \
# 0             2           2023               7            14
# 1             1           2023               3            23
# 2             1           2023               6            30
# 3             1           2019               8            23
# 4             1           2023               5            18
# 5             2           2023               6             1
# 6             2           2023               3            16
# 7             1           2023               7             7
# 8             1           2023               5            15
# 9             2           2023               3            17
#
#    in_spotify_playlists  in_spotify_charts    streams  in_apple_playlists  \
# 0                   553                147  141381703                  43
# 1                  1474                 48  133716286                  48
# 2                  1397                113  140003974                  94
# 3                  7858                100  800840817                 116
# 4                  3133                 50  303236322                  84
# 5                  2186                 91  183706234                  67
# 6                  3090                 50  725980112                  34
# 7                   714                 43   58149378                  25
# 8                  1096                 83   95217315                  60
# 9                  2953                 44  553634067                  49
#
#    ...  bpm key   mode danceability_%  valence_% energy_% acousticness_%  \
# 0  ...  125   B  Major             80         89       83             31
# 1  ...   92  C#  Major             71         61       74              7
# 2  ...  138   F  Major             51         32       53             17
# 3  ...  170   A  Major             55         58       72             11
# 4  ...  144   A  Minor             65         23       80             14
# 5  ...  141  C#  Major             92         66       58             19
# 6  ...  148   F  Minor             67         83       76             48
# 7  ...  100   F  Major             67         26       71             37
# 8  ...  130  C#  Minor             85         22       62             12
# 9  ...  170   D  Minor             81         56       48             21
#
#    instrumentalness_%  liveness_%  speechiness_%
# 0                   0           8              4
# 1                   0          10              4
# 2                   0          31              6
# 3                   0          11             15
# 4                  63          11              6
# 5                   0           8             24
# 6                   0           8              3
# 7                   0          11              4
# 8                   0          28              9
# 9                   0           8             33
#
# [10 rows x 24 columns]

# %% [markdown]
# **Question 2**
#
# Get the last 15 rows of the data

# %%
df.tail(15)
# Out:
#                         track_name               artist(s)_name  artist_count  \
# 938                      Labyrinth                 Taylor Swift             1
# 939                    Spin Bout U             Drake, 21 Savage             2
# 940                  Sweet Nothing                 Taylor Swift             1
# 941  Would've, Could've, Should've                 Taylor Swift             1
# 942                   Con La Brisa  Ludwig Goransson, Foudeqush             2
# 943             Privileged Rappers             Drake, 21 Savage             2
# 944                  The Astronaut                          Jin             1
# 945                BackOutsideBoyz                        Drake             1
# 946                     Broke Boys             Drake, 21 Savage             2
# 947                  The Great War                 Taylor Swift             1
# 948                   My Mind & Me                 Selena Gomez             1
# 949      Bigger Than The Whole Sky                 Taylor Swift             1
# 950           A Veces (feat. Feid)           Feid, Paulo Londra             2
# 951                  En La De Ella           Feid, Sech, Jhayco             3
# 952                          Alone                    Burna Boy             1
#
#      released_year  released_month  released_day  in_spotify_playlists  \
# 938           2022              10            21                  1597
# 939           2022              11             4                  1652
# 940           2022              10            21                  1747
# 941           2022              10            21                  1715
# 942           2022              11             4                   486
# 943           2022              11             4                  1007
# 944           2022              10            28                   481
# 945           2022              11             4                  1045
# 946           2022              11             4                  1060
# 947           2022              10            21                  1274
# 948           2022              11             3                   953
# 949           2022              10            21                  1180
# 950           2022              11             3                   573
# 951           2022              10            20                  1320
# 952           2022              11             4                   782
#
#      in_spotify_charts    streams  in_apple_playlists  ...  bpm  key   mode  \
# 938                  0  187339835                   6  ...  110  NaN  Major
# 939                  2  198365537                  26  ...  130    G  Major
# 940                  0  186104310                   9  ...  177  NaN  Major
# 941                  0  177503916                   4  ...  158    G  Major
# 942                  0   71095708                   8  ...  114    D  Minor
# 943                  0  112436403                   6  ...  144    F  Major
# 944                  9  203436468                  10  ...  125    F  Major
# 945                  0   93367537                   8  ...  142    F  Minor
# 946                  0  106249219                   3  ...  120    D  Major
# 947                  0  181382590                   1  ...   96    F  Major
# 948                  0   91473363                  61  ...  144    A  Major
# 949                  0  121871870                   4  ...  166   F#  Major
# 950                  0   73513683                   2  ...   92   C#  Major
# 951                  0  133895612                  29  ...   97   C#  Major
# 952                  2   96007391                  27  ...   90    E  Minor
#
#     danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 938             48         15       31             80                  22
# 939             77         20       70              1                   0
# 940             34         39       16             97                   0
# 941             48         55       84             43                   0
# 942             62         25       44             51                  33
# 943             93         62       61              0                   0
# 944             54         22       76              0                   0
# 945             85         40       43              4                   0
# 946             64         11       53              1                   0
# 947             57         55       74             22                   0
# 948             60         24       39             57                   0
# 949             42          7       24             83                   1
# 950             80         81       67              4                   0
# 951             82         67       77              8                   0
# 952             61         32       67             15                   0
#
#      liveness_%  speechiness_%
# 938          12              4
# 939          16              5
# 940          12              5
# 941          15             12
# 942          14              3
# 943          12             20
# 944          14              3
# 945          39             32
# 946          25             27
# 947           8              4
# 948           8              3
# 949          12              6
# 950           8              6
# 951          12              5
# 952          11              5
#
# [15 rows x 24 columns]

# %% [markdown]
# **Question 3**
#
# **What is the shape of the data i.e How many rows and columns**

# %%
df.shape
# 953 by 24
# Out:
# (953, 24)

# %% [markdown]
# **Question 4**
#
# Get the statistical information of the data

# %%
df.describe()
# df.describe(include = 'all') to see everything
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# 25%              875.000000           0.000000           13.000000
# 50%             2224.000000           3.000000           34.000000
# 75%             5542.000000          16.000000           88.000000
# max            52898.000000         147.000000          672.000000
#
#        in_apple_charts  in_deezer_charts         bpm  danceability_%  \
# count       953.000000        953.000000  953.000000       953.00000
# mean         51.908709          2.666317  122.540399        66.96957
# std          50.630241          6.035599   28.057802        14.63061
# min           0.000000          0.000000   65.000000        23.00000
# 25%           7.000000          0.000000  100.000000        57.00000
# 50%          38.000000          0.000000  121.000000        69.00000
# 75%          87.000000          2.000000  140.000000        78.00000
# max         275.000000         58.000000  206.000000        96.00000
#
#         valence_%    energy_%  acousticness_%  instrumentalness_%  liveness_%  \
# count  953.000000  953.000000      953.000000          953.000000  953.000000
# mean    51.431270   64.279119       27.057712            1.581322   18.213012
# std     23.480632   16.550526       25.996077            8.409800   13.711223
# min      4.000000    9.000000        0.000000            0.000000    3.000000
# 25%     32.000000   53.000000        6.000000            0.000000   10.000000
# 50%     51.000000   66.000000       18.000000            0.000000   12.000000
# 75%     70.000000   77.000000       43.000000            0.000000   24.000000
# max     97.000000   97.000000       97.000000           91.000000   97.000000
#
#        speechiness_%
# count     953.000000
# mean       10.131165
# std         9.912888
# min         2.000000
# 25%         4.000000
# 50%         6.000000
# 75%        11.000000
# max        64.000000

# %% [markdown]
# **Question 5**
#
# Get the info of the data so you can know the data types and some other information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
#  11  in_deezer_playlists   953 non-null    object
#  12  in_deezer_charts      953 non-null    int64
#  13  in_shazam_charts      903 non-null    object
#  14  bpm                   953 non-null    int64
#  15  key                   858 non-null    object
#  16  mode                  953 non-null    object
#  17  danceability_%        953 non-null    int64
#  18  valence_%             953 non-null    int64
#  19  energy_%              953 non-null    int64
#  20  acousticness_%        953 non-null    int64
#  21  instrumentalness_%    953 non-null    int64
#  22  liveness_%            953 non-null    int64
#  23  speechiness_%         953 non-null    int64
# dtypes: int64(17), object(7)
# memory usage: 178.8+ KB

# %% [markdown]
# **Question 6**
#
# Check the duplicates of the data. If there are duplicates, drop the duplicates

# %%
df.duplicated().sum()
# df.duplicated().any() to know if there's any duplicate
df.drop_duplicates()
df.duplicated().any()
# Out:
# False

# %% [markdown]
# **Question 7**
#
# How many null values do we have in the data

# %%
df.isnull().sum().sum()
# Out:
# 145

# %% [markdown]
# **Question 8**
#
# Which artist has the highest number of records in the data

# %%
df['artist(s)_name'].value_counts()
# # df.groupby('released_year')['artist(s)_name'].value_counts().reset_index() to see all the artists record
# # OR df[['artist(s)_name','released_year']].value_counts()
# # df['artist(s)_name'].value_counts().reset_index().iloc[0,0] to get only the name of the artist
# artists = df['artist(s)_name'].value_counts().reset_index()
# artists or you assign it to a variable and print it
# artists.iloc()[0,0]
# artists.iloc[-1,0] if you want the artist with the highest number of records from bottom
# you can also use the code.
# Out:
# artist(s)_name
# Taylor Swift                 34
# The Weeknd                   22
# Bad Bunny                    19
# SZA                          19
# Harry Styles                 17
#                              ..
# Karol G, Ovy On The Drums     1
# Coolio, L.V.                  1
# Kordhell                      1
# Kenia OS                      1
# Feid, Sech, Jhayco            1
# Name: count, Length: 645, dtype: int64

# %% [markdown]
# **Question 9**
#
# Who had the highest number of streams in the data

# %%
df['streams'].max()
# Out:
# 'BPM110KeyAModeMajorDanceability53Valence75Energy69Acousticness7Instrumentalness0Liveness17Speechiness3'

# %% [markdown]
# **Question 10**
#
# What is the average streams

# %%
df['streams'] = pd.to_numeric(df['streams'], errors='coerce')
df['streams'].mean()
# Out:
# 514137424.93907565

# %%
df['streams'] = pd.to_numeric(df['streams'], errors = 'coerce' )
df.query("streams == streams.max()")
# df.query("streams == streams.max()")['artist(s)_name'] to see only the artist that has the highest number of streams
# OR

df['streams'] == df['streams'].max()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 948    False
# 949    False
# 950    False
# 951    False
# 952    False
# Name: streams, Length: 953, dtype: bool

# %%
# OR
df.groupby('artist(s)_name')['streams'].max().sort_values(ascending = False).head()
# Out:
# artist(s)_name
# The Weeknd               3.703895e+09
# Ed Sheeran               3.562544e+09
# Lewis Capaldi            2.887242e+09
# Tones and I              2.864792e+09
# Post Malone, Swae Lee    2.808097e+09
# Name: streams, dtype: float64

# %% [markdown]
# **Question 11**
#
# Which artist released a song that was the most danceable

# %%
df['danceability_%'].max()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-294b38e18594> in <cell line: 1>()
# ----> 1 df['danceability_%'].max().sort_values(ascending = False).head()
#
# AttributeError: 'numpy.int64' object has no attribute 'sort_values'

# %%
df.groupby('artist(s)_name')['danceability_%'].max().sort_values(ascending = False).head(1)
# Out:
# artist(s)_name
# Ed Sheeran, Fireboy DML    96
# Name: danceability_%, dtype: int64

# %% [markdown]
# **Question 12**
#
# What day of the month do you think people like to release songs

# %%
df['released_day']  = pd.to_datetime(df['released_day'])
df['released_day'].value_counts()
# Out:
# released_day
# 1970-01-01 00:00:00.000000001    95
# 1970-01-01 00:00:00.000000021    44
# 1970-01-01 00:00:00.000000013    43
# 1970-01-01 00:00:00.000000024    40
# 1970-01-01 00:00:00.000000002    39
# 1970-01-01 00:00:00.000000020    39
# 1970-01-01 00:00:00.000000004    39
# 1970-01-01 00:00:00.000000007    39
# 1970-01-01 00:00:00.000000006    39
# 1970-01-01 00:00:00.000000010    37
# 1970-01-01 00:00:00.000000009    36
# 1970-01-01 00:00:00.000000022    33
# 1970-01-01 00:00:00.000000003    32
# 1970-01-01 00:00:00.000000025    28
# 1970-01-01 00:00:00.000000017    28
# 1970-01-01 00:00:00.000000014    26
# 1970-01-01 00:00:00.000000008    25
# 1970-01-01 00:00:00.000000019    25
# 1970-01-01 00:00:00.000000005    25
# 1970-01-01 00:00:00.000000023    23
# 1970-01-01 00:00:00.000000029    23
# 1970-01-01 00:00:00.000000030    22
# 1970-01-01 00:00:00.000000011    22
# 1970-01-01 00:00:00.000000028    21
# 1970-01-01 00:00:00.000000027    21
# 1970-01-01 00:00:00.000000015    21
# 1970-01-01 00:00:00.000000016    20
# 1970-01-01 00:00:00.000000031    19
# 1970-01-01 00:00:00.000000018    19
# 1970-01-01 00:00:00.000000012    17
# 1970-01-01 00:00:00.000000026    13
# Name: count, dtype: int64

# %%
df['released_day'].mode()[0]
# Out:
# 1

# %% [markdown]
# **Question 13**
#
# What month do people like to release their songs

# %%
df['released_month'].value_counts()
# Out:
# released_month
# 1     134
# 5     128
# 3      86
# 6      86
# 11     80
# 12     75
# 10     73
# 4      66
# 7      62
# 2      61
# 9      56
# 8      46
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['track_name', 'artist(s)_name', 'artist_count', 'released_year',
#        'released_month', 'released_day', 'in_spotify_playlists',
#        'in_spotify_charts', 'streams', 'in_apple_playlists', 'in_apple_charts',
#        'in_deezer_playlists', 'in_deezer_charts', 'in_shazam_charts', 'bpm',
#        'key', 'mode', 'danceability_%', 'valence_%', 'energy_%',
#        'acousticness_%', 'instrumentalness_%', 'liveness_%', 'speechiness_%'],
#       dtype='object')

# %%
df['released_months'] = pd.to_datetime(df['released_day'].dt.month)
df['released_months'].value_counts()
# Out:
# released_months
# 1970-01-01 00:00:00.000000001    953
# Name: count, dtype: int64

# %%
# Out:
#      released_month                  artist(s)_name  count
# 0                 1                      The Weeknd     13
# 1                 1                    Taylor Swift      5
# 2                 1                          Eminem      4
# 3                 1                      Ed Sheeran      3
# 4                 1                   Morgan Wallen      3
# ..              ...                             ...    ...
# 777              12                        Libianca      1
# 778              12                       Luar La L      1
# 779              12  MC Xenon, Os Gemeos da Putaria      1
# 780              12              Marï¿½ï¿½lia Mendo      1
# 781              12                       Yng Lvcas      1
#
# [782 rows x 3 columns]

# %% [markdown]
# **Question 14**
#
# Do people sing solo more or they feature other artists

# %%
df.head(2)
# Out:
#                             track_name    artist(s)_name  artist_count  \
# 0  Seven (feat. Latto) (Explicit Ver.)  Latto, Jung Kook             2
# 1                                 LALA       Myke Towers             1
#
#    released_year  released_month  released_day  in_spotify_playlists  \
# 0           2023               7            14                   553
# 1           2023               3            23                  1474
#
#    in_spotify_charts      streams  in_apple_playlists  ...  bpm key   mode  \
# 0                147  141381703.0                  43  ...  125   B  Major
# 1                 48  133716286.0                  48  ...   92  C#  Major
#
#   danceability_%  valence_% energy_% acousticness_%  instrumentalness_%  \
# 0             80         89       83             31                   0
# 1             71         61       74              7                   0
#
#    liveness_%  speechiness_%
# 0           8              4
# 1          10              4
#
# [2 rows x 24 columns]

# %%
df['artist_count'].value_counts()
# Out:
# artist_count
# 1    587
# 2    254
# 3     85
# 4     15
# 5      5
# 6      3
# 8      2
# 7      2
# Name: count, dtype: int64

# %% [markdown]
# **Question 15**
#
# In what year did people release songs more

# %%
df['released_year'].value_counts()
# Out:
# released_year
# 2022    402
# 2023    175
# 2021    119
# 2020     37
# 2019     36
# 2017     23
# 2016     18
# 2014     13
# 2013     13
# 2015     11
# 2018     10
# 2012     10
# 2011     10
# 2010      7
# 2002      6
# 1999      5
# 1984      4
# 2000      4
# 2004      4
# 1963      3
# 1958      3
# 1995      2
# 1970      2
# 1959      2
# 1985      2
# 1957      2
# 1986      2
# 2003      2
# 1991      2
# 2008      2
# 1975      2
# 1982      2
# 1946      1
# 2005      1
# 1942      1
# 1996      1
# 1998      1
# 1950      1
# 1979      1
# 2007      1
# 1952      1
# 1971      1
# 1994      1
# 1930      1
# 1973      1
# 1997      1
# 1968      1
# 1992      1
# 1983      1
# 1987      1
# Name: count, dtype: int64

# %% [markdown]
# **Question 16**
#
# Use the groupby to get the number of songs released in each month of the year

# %%
df.groupby('released_month')['released_month'].value_counts()
# Out:
# released_month
# 1     134
# 2      61
# 3      86
# 4      66
# 5     128
# 6      86
# 7      62
# 8      46
# 9      56
# 10     73
# 11     80
# 12     75
# Name: count, dtype: int64

# %%
df.groupby('released_months') ['track_name'].count()
# Out:
# released_months
# 1970-01-01 00:00:00.000000001    953
# Name: track_name, dtype: int64

# %%
# df.groupby('released_month')['artist(s)_name'].value_counts().reset_index().sort_values(by = 'count',ascending = ) the same

# %% [markdown]
# **Question 17**
#
# Whose song did not really make a hit in terms of streams

# %%
df['streams'].min()
# Out:
# 2762.0

# %%
df.query("streams == streams.min()")
# Out:
#       track_name              artist(s)_name  artist_count  released_year  \
# 123  Que Vuelvas  Carin Leon, Grupo Frontera             2           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 123              12             9                   763                 26
#
#      streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 123   2762.0                  21  ...  162  A#  Major             49
#
#      valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 123         78       64             19                   0          11
#
#      speechiness_%
# 123              4
#
# [1 rows x 24 columns]

# %% [markdown]
# **Question 18**
#
# What song had the highest number of streams on the apple playlist

# %%
df.query("streams == streams.max()")
# Out:
#          track_name artist(s)_name  artist_count  released_year  \
# 55  Blinding Lights     The Weeknd             1           2019
#
#     released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 55              11            29                 43899                 69
#
#          streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 55  3.703895e+09                 672  ...  171  C#  Major             50
#
#     valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 55         38       80              0                   0           9
#
#     speechiness_%
# 55              7
#
# [1 rows x 24 columns]

# %%
df['in_apple_charts'].value_counts()
# Out:
# in_apple_charts
# 0      100
# 1       40
# 2       26
# 3       24
# 6       16
#       ...
# 199      1
# 144      1
# 148      1
# 181      1
# 141      1
# Name: count, Length: 172, dtype: int64

# %% [markdown]
# **Question 19**
#
# What song had the highest number of streams on the spotify playlist

# %%
df.query("in_spotify_playlists == in_spotify_playlists.max()")
# Out:
#                  track_name                              artist(s)_name  \
# 757  Get Lucky - Radio Edit  Pharrell Williams, Nile Rodgers, Daft Punk
#
#      artist_count  released_year  released_month  released_day  \
# 757             3           2013               1             1
#
#      in_spotify_playlists  in_spotify_charts      streams  in_apple_playlists  \
# 757                 52898                  0  933815613.0                 203
#
#      ...  bpm key   mode danceability_%  valence_% energy_% acousticness_%  \
# 757  ...  116  F#  Minor             79         87       81              4
#
#      instrumentalness_%  liveness_%  speechiness_%
# 757                   0          10              4
#
# [1 rows x 24 columns]

# %%
df['in_spotify_charts'].value_counts()
# Out:
# in_spotify_charts
# 0      405
# 4       48
# 2       42
# 6       36
# 3       18
#       ...
# 76       1
# 58       1
# 79       1
# 66       1
# 147      1
# Name: count, Length: 82, dtype: int64

# %% [markdown]
# **Question 20**
#
# What track had the highest number of streams

# %%
df.query("streams == streams.max()")
# Out:
#          track_name artist(s)_name  artist_count  released_year  \
# 55  Blinding Lights     The Weeknd             1           2019
#
#     released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 55              11            29                 43899                 69
#
#          streams  in_apple_playlists  ...  bpm key   mode danceability_%  \
# 55  3.703895e+09                 672  ...  171  C#  Major             50
#
#     valence_% energy_% acousticness_%  instrumentalness_%  liveness_%  \
# 55         38       80              0                   0           9
#
#     speechiness_%
# 55              7
#
# [1 rows x 24 columns]

# %%
df['streams'].max()
# Out:
# 3703895074.0

# %%
df.query("streams == streams.max()").iloc[0,1]
# Out:
# 'The Weeknd'

# %%
df.query("streams == streams.max()").loc[:,'track_name']
# no numbers when using loc
# Out:
# 55    Blinding Lights
# Name: track_name, dtype: object
