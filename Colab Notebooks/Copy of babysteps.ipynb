# %%
a = 6
b = 4


print(a-b)
# Out:
# 2

# %% [markdown]
# Today is the first class in python

# %%
print(b-a) #i am trying to do an arithemetic operation
# Out:
# -2

# %%
print("hello world !")
# Out:
# hello world !

# %%
print('Welcome to python programming class')
# Out:
# Welcome to python programming class

# %%
print("Python Print Function")
print("The function is declared like this:")
print('print("what to print")')
# Out:
# Python Print Function
# The function is declared like this:
# print("what to print")

# %%
"Python Print Function"
"The function is declared like this:"
"print('what to print')"
# Out:
# "print('what to print')"

# %%
print("Bola's age is 80")
# Out:
# Bola's age is 80

# %%
print("hello world ")
print("hello world ")
print("hello world ")
# Out:
# hello world
# hello world
# hello world

# %%
print("hello world \nhello world\nhello world ")
# Out:
# hello world
# hello world
# hello world

# %%
print("Ikenna\nCynthia\nLekanAsisat")
# Out:
# Ikenna
# Cynthia
# LekanAsisat

# %%
print("Ikenna" + "X")
# Out:
# IkennaX

# %%
print("Goriola " + "Idris")
# Out:
# Goriola Idris

# %%
print("Age of Bola is" , 90)
# Out:
# Age of Bola is 90

# %%
print("Azizat" + " " + "Sulaiman")
# Out:
# Azizat Sulaiman

# %%
input('Enter your name')
# Out:
# Enter your namJacob
# 'Jacob'

# %%
type(input('Enter your age: '))
# Out:
# Enter your age: lekan
# str

# %%
a = 8
b = 7

c = b - a

# %%
print(c)
# Out:
# -1

# %%
name = 'lekan'

# %%
print(name)
# Out:
# lekan

# %% [markdown]
# Conditional Statements

# %%
if 2>3:
  print('Excellent')
else:
  print('Bad')
# Out:
# Bad

# %%
num = -1

if num > 0:
	print(num, "is a positive number.")
	print("This is always printed.")

else:
  print(num, 'not greater than 0')
# Out:
# -1 not greater than 0

# %%
x=5

if x==1:
      print('X is equal to 1')
elif x==5:
      print('X is equal to 5')
      if x > 5:
        print('Greater than 5')
      else:
        print('Not greater')
elif x==10:
      print('X is equal to 10')
else:
      print('X =', x)
# Out:
# X is equal to 5
# Not greater

# %%
status = input('Enter the status of weather. E.g Rain or Shiny ') #input

#conditional statement
if status == 'Rain':
  print('I will not go to church')
else:
  print('I will go to church')
# Out:
# Enter the status of weather. E.g Rain or Shiny Shiny
# I will go to church

# %%
a = 4
print('A') if a > 4 else print('B')
# Out:
# B

# %% [markdown]
# write a program that checks if order is ready, if the order is ready print food will be served soon, else print your food won't be served soon

# %%
y = 50

if y > 50:
  print('Y is greater than 50')
elif y > 30:
  print('Y not good')
if y > 40:
  print('Y is greater than 40')
else:
  print('Y is okay')
# Out:
# Y not good
# Y is greater than 40

# %%
True == False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
order_total = 150
customer_membership = True

if order_total >= 100 and customer_membership == True:
    print("Discount applied.")
else:
    print("Discount not applied.")
# Out:
# Discount not applied.

# %%
order_total = 75
customer_location = "USA"

if order_total >= 500 or customer_location == "NIgeria":
    print("Free shipping applied.")
else:
    print("Shipping fee applied.")
# Out:
# Shipping fee applied.

# %%
not(False)
# Out:
# True

# %%
is_member = True

if not is_member:
    print("Customer is not a member.")
else:
    print("Customer is a member.")
# Out:
# Customer is a member.

# %%
5 - 4
# Out:
# 1

# %%
15 % 4
# Out:
# 3

# %%
#continuation

# %%
print(2**2)
# Out:
# 4

# %%
print(2**7)
# Out:
# 128

# %%
print(6/4)
# Out:
# 1.5

# %%
round(8/3, 2)
# Out:
# 2.67

# %%
8/3
# Out:
# 2.6666666666666665

# %%
a = 2
a /=2
print(a)
# Out:
# 1.0

# %%
a  = 10
a = a / 4
print(a)
# Out:
# 2.5

# %%
a  = 10
a /= 4
print(a)
# Out:
# 2.5

# %%
score = 15
print("Your score is " + str(score))
# Out:
# Your score is 15

# %%
score = 15
al_score = 11
print(f"Your score is {score} & {al_score}")
# Out:
# Your score is 15 & 11

# %%
score = 15
print("Your score is ",score)
# Out:
# Your score is  15
