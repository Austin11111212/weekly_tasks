# %%
# !pip install pandas

# %%
import pandas as pd

# %%
df = pd.read_ipynb('/content/ydata_profiling.ipynb')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-8-193302cce296> in <cell line: 1>()
# ----> 1 df = pd.read_ipynb('/content/ydata_profiling.ipynb')
#
# AttributeError: module 'pandas' has no attribute 'read_ipynb'
