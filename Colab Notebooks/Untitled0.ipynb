# %%
import numpy as np

# Extract loan amounts from the data
loan_amounts = loan_data[:, 5]  # Assuming loan amount is in the 6th column (index 5)

# Calculate mean, median, and standard deviation
mean_amount = np.mean(loan_amounts)
median_amount = np.median(loan_amounts)
std_dev_amount = np.std(loan_amounts)

# Print the results
print("Mean loan amount:", mean_amount)
print("Median loan amount:", median_amount)
print("Standard deviation of loan amount:", std_dev_amount)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a61060ee0664> in <cell line: 4>()
#       2
#       3 # Extract loan amounts from the data
# ----> 4 loan_amounts = loan_data[:, 5]  # Assuming loan amount is in the 6th column (index 5)
#       5
#       6 # Calculate mean, median, and standard deviation
#
# NameError: name 'loan_data' is not defined
